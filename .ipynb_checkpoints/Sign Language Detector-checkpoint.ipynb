# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import time
import mediapipe as mp
import os
# Out:
# 2023-07-23 15:02:34.705385: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-23 15:02:35.241196: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import tensorflow as tf

# %% [markdown]
# ### We will use MediaPipe's Holistic models to track keypoints from images

# %%
# Getting the holistic model and initializing it
mp_holistic = mp.solutions.holistic
# Getting the drawing utilities for plotting points
mp_drawing = mp.solutions.drawing_utils

# %%
# Function to detect points in our image
def mp_detection(image, model):
    # Converting BGR image of OpenCV into RGB
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    rgb_image.flags.writeable = False # Non-writeable
    
    # Process the image using mediapipe model
    result = model.process(rgb_image)
    rgb_image.flags.writeable = True # Writeable
    
    # Changing it back to BGR format for OpenCV
    bgr_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2BGR)
    return bgr_image, result

# %% [markdown]
# ### We need to access our camera as we loop through all frames and render them

# %%
# Plotting all keypoints on the image
def draw_landmarks(image, result):
    mp_drawing.draw_landmarks(image, result.face_landmarks, mp_holistic.FACEMESH_CONTOURS)
    mp_drawing.draw_landmarks(image, result.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
    mp_drawing.draw_landmarks(image, result.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image, result.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
# Plotting all keypoints on the image
def draw_styled_landmarks(image, result):
    # Draw face connections
    mp_drawing.draw_landmarks(image, result.face_landmarks, mp_holistic.FACEMESH_CONTOURS,
                             mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                             mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
                             )
    # Draw pose connections
    mp_drawing.draw_landmarks(image, result.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, result.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, result.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cam = cv2.VideoCapture(0)
# Accessing MP Model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cam.isOpened():
        # Reading current frame from video
        retval, frame = cam.read()

        # Detect points/landmarks and draw them
        image, result = mp_detection(frame, holistic)
        draw_styled_landmarks(image, result)

        # Display frame
        cv2.imshow('Rendered Output', image)
        
        # Break if we press 'q'
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    # Stop capturing video 
    cam.release()
    cv2.destroyAllWindows()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ### Now we extract the keypoint values to use it as our data

# %%
# All landmarks are stored in result
len(result.face_landmarks.landmark)
# Out:
# 468

# %%
len(result.pose_landmarks.landmark)
# Out:
# 33

# %%
len(result.left_hand_landmarks.landmark)
# Out:
# 21

# %%
def extract_keypoints(result):
    # Each pose landmark has 4 attributes so total values = 33 x 4
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in result.pose_landmarks.landmark]).flatten() if result.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in result.left_hand_landmarks.landmark]).flatten() if result.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in result.right_hand_landmarks.landmark]).flatten() if result.right_hand_landmarks else np.zeros(21*3)
    face = np.array([[res.x, res.y, res.z] for res in result.face_landmarks.landmark]).flatten() if result.face_landmarks else np.zeros(468*3)
    return np.concatenate([pose, face, lh, rh])

# %%
extract_keypoints(result).shape
# Out:
# (1662,)

# %% [markdown]
# ### Now we will setup our directories for storing our extracted keypoints

# %%
DATA_PATH = os.path.join('MP_Data')

# Actions that we try to detect
actions = np.array(['Hello', 'Thanks', 'I Love You'])
# Data consisting of 30 videos/sequences each of length = 30 frames
no_sequences = 30
sequence_length = 30

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# ### Now we need to gather data for training

# %%
cam = cv2.VideoCapture(0)
# Accessing MP Model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        for sequence in range(no_sequences):
            for frame_count in range(sequence_length):
                # Reading current frame from video
                retval, frame = cam.read()

                # Detect points/landmarks and draw them
                image, result = mp_detection(frame, holistic)
                draw_styled_landmarks(image, result)
                
                # Setting durations and counters
                if frame_count == 0:
                    cv2.putText(image, 'Starting Collection...', (120, 500),
                               cv2.FONT_HERSHEY_DUPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} for Video {}'.format(action, sequence), (15,12),
                                cv2.FONT_HERSHEY_DUPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Display frame
                    cv2.imshow('Rendered Output', image)

                    cv2.waitKey(1500)
                else:
                    cv2.putText(image, 'Collecting frames for {} for Video {}'.format(action, sequence), (15,12),
                                cv2.FONT_HERSHEY_DUPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Display frame
                    cv2.imshow('Rendered Output', image)

                # Extracting and exporting keypoints from the frame
                keypoints = extract_keypoints(result)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_count))
                np.save(npy_path, keypoints)
                
                
                # Break if we press 'q'
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
    # Stop capturing video 
    cam.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ### Now we need to preprocess our data

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}
label_map
# Out:
# {'Hello': 0, 'Thanks': 1, 'I Love You': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_count in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_count)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)
X.shape
# Out:
# (90, 30, 1662)

# %%
# Creates one hot-encoded label array
y = to_categorical(labels).astype(int)
y.shape
# Out:
# (90, 3)

# %%
# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %%
X_train.shape
# Out:
# (81, 30, 1662)

# %%
X_test.shape
# Out:
# (9, 30, 1662)

# %% [markdown]
# ### Now we will build our model for prediction

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
# Out:
# 2023-07-23 15:03:35.356471: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model compilation
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
# Model training
model.fit(X_train, y_train, epochs=150, callbacks=[tb_callback])
# Out:
# Epoch 1/150
# 2023-07-23 13:31:36.999210: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 16154640 exceeds 10% of free system memory.
# 3/3 [==============================] - 1s 137ms/step - loss: 0.2301 - categorical_accuracy: 0.8889
# Epoch 2/150
# 3/3 [==============================] - 0s 127ms/step - loss: 0.2376 - categorical_accuracy: 0.9012
# Epoch 3/150
# 3/3 [==============================] - 0s 135ms/step - loss: 0.2239 - categorical_accuracy: 0.8889
# Epoch 4/150
# 3/3 [==============================] - 0s 150ms/step - loss: 0.2055 - categorical_accuracy: 0.9136
# Epoch 5/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.2709 - categorical_accuracy: 0.8765
# Epoch 6/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.3336 - categorical_accuracy: 0.9136
# Epoch 7/150
# 3/3 [==============================] - 0s 101ms/step - loss: 0.2930 - categorical_accuracy: 0.8395
# Epoch 8/150
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2898 - categorical_accuracy: 0.8642
# Epoch 9/150
# 3/3 [==============================] - 0s 117ms/step - loss: 0.3373 - categorical_accuracy: 0.8765
# Epoch 10/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.3133 - categorical_accuracy: 0.8765
# Epoch 11/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.2990 - categorical_accuracy: 0.8642
# Epoch 12/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.2646 - categorical_accuracy: 0.8889
# Epoch 13/150
# 3/3 [==============================] - 0s 107ms/step - loss: 0.2840 - categorical_accuracy: 0.9012
# Epoch 14/150
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2424 - categorical_accuracy: 0.8889
# Epoch 15/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2339 - categorical_accuracy: 0.8889
# Epoch 16/150
# 3/3 [==============================] - 0s 110ms/step - loss: 0.2312 - categorical_accuracy: 0.9136
# Epoch 17/150
# 3/3 [==============================] - 0s 124ms/step - loss: 0.2271 - categorical_accuracy: 0.8889
# Epoch 18/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.2932 - categorical_accuracy: 0.8765
# Epoch 19/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.3483 - categorical_accuracy: 0.8765
# Epoch 20/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0723 - categorical_accuracy: 0.9877
# Epoch 90/150
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0988 - categorical_accuracy: 0.9630
# Epoch 91/150
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0977 - categorical_accuracy: 0.9753
# Epoch 92/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0745 - categorical_accuracy: 0.9877
# Epoch 93/150
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0665 - categorical_accuracy: 0.9877
# Epoch 94/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0674 - categorical_accuracy: 0.9753
# Epoch 95/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0619 - categorical_accuracy: 0.9753
# Epoch 96/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0737 - categorical_accuracy: 0.9877
# Epoch 97/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0962 - categorical_accuracy: 0.9630
# Epoch 98/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2110 - categorical_accuracy: 0.9506
# Epoch 99/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.1654 - categorical_accuracy: 0.9506
# Epoch 100/150
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1538 - categorical_accuracy: 0.9383
# Epoch 101/150
# 3/3 [==============================] - 0s 81ms/step - loss: 0.2022 - categorical_accuracy: 0.8889
# Epoch 102/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.1040 - categorical_accuracy: 0.9259
# Epoch 103/150
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1823 - categorical_accuracy: 0.9383
# Epoch 104/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1253 - categorical_accuracy: 0.9383
# Epoch 105/150
# 3/3 [==============================] - 0s 117ms/step - loss: 0.1218 - categorical_accuracy: 0.9506
# Epoch 106/150
# 3/3 [==============================] - 0s 110ms/step - loss: 0.1199 - categorical_accuracy: 0.9506
# Epoch 107/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1163 - categorical_accuracy: 0.9506
# Epoch 108/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1057 - categorical_accuracy: 0.9383
# Epoch 109/150
# 3/3 [==============================] - 0s 131ms/step - loss: 0.0875 - categorical_accuracy: 0.9753
# Epoch 110/150
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0721 - categorical_accuracy: 0.9753
# Epoch 111/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0798 - categorical_accuracy: 0.9630
# Epoch 112/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0694 - categorical_accuracy: 0.9506
# Epoch 113/150
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0943 - categorical_accuracy: 0.9630
# Epoch 114/150
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0655 - categorical_accuracy: 0.9753
# Epoch 115/150
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0461 - categorical_accuracy: 0.9877
# Epoch 116/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.1239 - categorical_accuracy: 0.9506
# Epoch 117/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.1151 - categorical_accuracy: 0.9506
# Epoch 118/150
# 3/3 [==============================] - 0s 101ms/step - loss: 0.2504 - categorical_accuracy: 0.9383
# Epoch 119/150
# 3/3 [==============================] - 0s 99ms/step - loss: 0.2713 - categorical_accuracy: 0.9136
# Epoch 120/150
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1656 - categorical_accuracy: 0.9383
# Epoch 121/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1236 - categorical_accuracy: 0.9383
# Epoch 122/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1556 - categorical_accuracy: 0.9259
# Epoch 123/150
# 3/3 [==============================] - 0s 106ms/step - loss: 0.1130 - categorical_accuracy: 0.9877
# Epoch 124/150
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0987 - categorical_accuracy: 0.9630
# Epoch 125/150
# 3/3 [==============================] - 0s 128ms/step - loss: 0.1231 - categorical_accuracy: 0.9506
# Epoch 126/150
# 3/3 [==============================] - 0s 106ms/step - loss: 0.1077 - categorical_accuracy: 0.9753
# Epoch 127/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0752 - categorical_accuracy: 0.9753
# Epoch 128/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.1515 - categorical_accuracy: 0.9259
# Epoch 129/150
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0710 - categorical_accuracy: 0.9753
# Epoch 130/150
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0517 - categorical_accuracy: 0.9877
# Epoch 131/150
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0361 - categorical_accuracy: 1.0000
# Epoch 132/150
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0183 - categorical_accuracy: 1.0000
# Epoch 133/150
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0259 - categorical_accuracy: 0.9877
# Epoch 134/150
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0500 - categorical_accuracy: 0.9753
# Epoch 135/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0543 - categorical_accuracy: 0.9753
# Epoch 136/150
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0222 - categorical_accuracy: 1.0000
# Epoch 137/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0495 - categorical_accuracy: 0.9877
# Epoch 138/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0321 - categorical_accuracy: 0.9877
# Epoch 139/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.1963 - categorical_accuracy: 0.9259
# Epoch 140/150
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0455 - categorical_accuracy: 0.9753
# Epoch 141/150
# 3/3 [==============================] - 0s 124ms/step - loss: 0.1603 - categorical_accuracy: 0.9506
# Epoch 142/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0763 - categorical_accuracy: 0.9630
# Epoch 143/150
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1071 - categorical_accuracy: 0.9630
# Epoch 144/150
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0740 - categorical_accuracy: 0.9753
# Epoch 145/150
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0282 - categorical_accuracy: 0.9877
# Epoch 146/150
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0853 - categorical_accuracy: 0.9630
# Epoch 147/150
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0234 - categorical_accuracy: 0.9877
# Epoch 148/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0417 - categorical_accuracy: 0.9877
# Epoch 149/150
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0463 - categorical_accuracy: 0.9877
# Epoch 150/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0118 - categorical_accuracy: 1.0000

# %%
model.load_weights('action1.h5')

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 387ms/step

# %% [markdown]
# ### Let us check the score of our model

# %%
def calculate_score(model, X_test, y_test):
    res = model.predict(X_test)
    total = X_test.shape[0]
    count = 0
    for i in range(total):
        if actions[np.argmax(res[i])] == actions[np.argmax(y_test[i])]:
            count = count+1
    print("Model Prediction Accuracy: ", (count*100)/total, '%')
    return

# %%
calculate_score(model, X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Model Prediction Accuracy:  100.0 %

# %% [markdown]
# ### Saving model and its weights

# %%
model.save('action1.h5')

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
y_hat = model.predict(X_test)
y_hat = np.argmax(y_hat, axis=1).tolist()
y_true = np.argmax(y_test, axis=1).tolist()
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
multilabel_confusion_matrix(y_true, y_hat)
# Out:
# array([[[6, 0],
#         [0, 3]],
#
#        [[7, 0],
#         [0, 2]],
#
#        [[5, 0],
#         [0, 4]]])

# %%
# Let us check it against training data
calculate_score(model, X_train, y_train)
# Out:
# 3/3 [==============================] - 0s 18ms/step
# Model Prediction Accuracy:  97.53086419753086 %

# %%
y_hat_train = model.predict(X_train)
y_hat_train = np.argmax(y_hat_train, axis=1).tolist()
y_true_train = np.argmax(y_train, axis=1).tolist()
multilabel_confusion_matrix(y_true_train, y_hat_train)
# Out:
# 3/3 [==============================] - 0s 18ms/step
# array([[[54,  0],
#         [ 2, 25]],
#
#        [[53,  0],
#         [ 0, 28]],
#
#        [[53,  2],
#         [ 0, 26]]])

# %% [markdown]
# ### Real-time testing

# %%
colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0, 60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255),
                   2, cv2.LINE_AA)
    
    return output_frame

# %%
plt.imshow(image)

# %%
from scipy import stats

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.5

cam = cv2.VideoCapture(0)
# Accessing MP Model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cam.isOpened():
        # Reading current frame from video
        retval, frame = cam.read()

        # Detect points/landmarks and draw them
        image, result = mp_detection(frame, holistic)
        draw_styled_landmarks(image, result)
        
        # Prediction 
        keypoints = extract_keypoints(result)
        #sequence.insert(0, keypoints)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence)==30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
        
        # Visualization
            if np.unique(predictions[-10:])[0]==np.argmax(res):
                if res[np.argmax(res)] > threshold:
                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 1:
                sentence = sentence[-1:]
                
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, " ".join(sentence), (3, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Display frame
        cv2.imshow('Rendered Output', image)
        
        # Break if we press 'q'
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    # Stop capturing video 
    cam.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 22ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 22ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 20ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 16ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 20ms/step
# Hello
# 1/1 [==============================] - 0s 20ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 21ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 21ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 24ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 23ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 21ms/step
# Hello
# 1/1 [==============================] - 0s 21ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 25ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 21ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 23ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 21ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 23ms/step
# Hello
# 1/1 [==============================] - 0s 23ms/step
# Hello
# 1/1 [==============================] - 0s 26ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 22ms/step
# Hello
# 1/1 [==============================] - 0s 23ms/step
# Hello
# 1/1 [==============================] - 0s 23ms/step
# Hello
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 23ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 22ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# Hello
# 1/1 [==============================] - 0s 20ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 20ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 20ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 16ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 20ms/step
# Thanks
# 1/1 [==============================] - 0s 21ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 22ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 17ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 19ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# Thanks
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 17ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# Hello
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 20ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 17ms/step
# I Love You
# 1/1 [==============================] - 0s 21ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 18ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You
# 1/1 [==============================] - 0s 19ms/step
# I Love You

# %%
res = model.predict(X_test)[0]
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
if res[np.argmax(res)] > threshold:
    print(actions[np.argmax(res)])
# Out:
# I Love You
